# %%
import numpy as np
from numpy.random import default_rng
from hyppo.independence import FriedmanRafsky
import csv

_OUT_PATH = './output_folder/output.csv' # output location

# %%
# Helper method: format the input for the Friedman Rafsky test.
def combine_then_label(x1, x2):
    return_X = np.concatenate([x1, x2])

    n1 = x1.shape[0]
    n2 = x2.shape[0]

    return_Y = np.repeat([1, 2], [n1, n2])

    return return_X, return_Y

# %%
# Helper method: select methods for data simulation

def get_data_simulator_list():
    # parameters for data simulators
    shape_1 = (10, 2)
    shape_2 = (100, 2)
    mean = [0, 0]
    cov = [[1, 0], [0, 100]]

    # methods from numpy (np)
    np_method_names = [
        ("zeros", {"shape": shape_1}),
        ("ones", {"shape": shape_1, "dtype": np.int8})
    ]

    # methods from numpy.random.default_rng
    rng_method_names = [
        ("uniform", {"low": 0, "high": 1000, "size": shape_1}),
        ("uniform", {"low": 2000, "high": 5000, "size": shape_1}),
        ("uniform", {"low": -1000, "high": 1000, "size": shape_1}),
        ("uniform", {"low": -1000, "high": 1000, "size": shape_2}),
        ("multivariate_normal", {"mean": mean, "cov": cov, "size": shape_1[0]}),
        ("multivariate_normal", {"mean": mean, "cov": cov, "size": shape_2[0]})
    ]

    # list to hold data generation methods
    base_datasets_method_components = []

    # get the methods that are sourced from Numpy object
    for method, params in np_method_names:

        source_object_string = "np"
        method_components = {
            "name" : method,
            "params" : params,
            "source_object" : source_object_string,
            "n" : params["shape"][0],
        }
        base_datasets_method_components.append(method_components)

    # get the methods that are sourced from Numpy.Random.default_generator
    for method, params in rng_method_names:
        if(method == "uniform"):
            n = params["size"][0]
        if(method== "multivariate_normal"):
            n = params["size"]

        source_object_string = "rng"
        method_components = {
            "name" : method,
            "params" : params,
            "source_object" : source_object_string,
            "n" : n,
        }
        base_datasets_method_components.append(method_components)

    return base_datasets_method_components

# %%
# Helper method: print info about the data being tested
def report_state(c1, c2):
    p = c1
    print(f"Running test with pair:")
    print(
        f"\t- {p['name']}({(p['params'])}), seed = {p['seed']}"
    )
    p = c2
    print(
        f"\t- {p['name']}({(p['params'])}), seed = {p['seed']}"
    )

# %%
# Helper method: run Friednman Rafsky and output the following:
# - pvalue
# - corrected test statistics
# - uncorrected test statistic
# - params that generated the data

def make_data(components, seed):
    module_map = {
        "rng": default_rng(seed),
        "np" : np
    }
    components["seed"] = seed

    source_object = module_map[components["source_object"]]
    method_name = components["name"]
    params = components["params"]

    data = getattr(source_object, method_name)(**params)
    return data

def run_FR_simtest(components_1, components_2, independence_expected):
    seed_1 = 402
    seed_2 = 404


    x1 = make_data(components_1, seed_1)
    x2 = make_data(components_2, seed_2)
    
    report_state(components_1, components_2)

    x,y = combine_then_label(x1, x2)
    method = FriedmanRafsky()
    test_rslt = method.test(x,y)
    statistic_rslt = method.statistic(x,y) # uncorrected test statistic

    print(f"test method output: \n\tstatistic: {test_rslt[0]}\n\tpvalue: {test_rslt[1]}")
    print(f"statisc method output: {statistic_rslt}")
    
    # Result to return to be written to csv
    row = {
        "test_rslt_statistic": test_rslt[0], 
        "test_rslt_pvalue": test_rslt[1], 
        "statistic_rslt": statistic_rslt,
        "independence_excepted": independence_expected,
        "n": components_1['n'],
        "m": components_2['n'],
        "dataset_1_info": (components_1),  # (type, parameters, n, seed)"
        "dataset_2_info": (components_2)   # (type, parameters, m, seed)"
    }

    return row

# %%
# Helper method: write to csv output
def save_results(rows):

    # each row is stored as a dict, so use the keys as field names
    field_names = rows[0].keys()
    print(f'Creating csv with field names:\n\t {field_names}')

    with open(_OUT_PATH, 'w') as fp:
        writer = csv.DictWriter(
            fp, fieldnames=field_names, 
            delimiter=',', 
            quotechar='"', 
            quoting=csv.QUOTE_MINIMAL
        )
        writer.writeheader()
        writer.writerows(rows)

# %%
def main_loop():
    self_compare_list = [
        "uniform",
        "multivariate"
    ]

    output_rows = []

    simulator_components_list = get_data_simulator_list()


    for i in range(len(simulator_components_list)):
        simulator_components = simulator_components_list[i]
        method_name = simulator_components["name"]

        if(method_name in self_compare_list):
            print("Running self_compare test:")
            output_rows.append(
                run_FR_simtest(
                    components_1=simulator_components,
                    components_2=simulator_components,
                    independence_expected=False
                )
            )
        for j in range(i, len(simulator_components_list)):
            if(j != i):
                simulator_components_2 = simulator_components_list[j]
                output_rows.append(
                    run_FR_simtest(
                        components_1=simulator_components,
                        components_2=simulator_components_2,
                        independence_expected=True
                    )
                )

    if(not output_rows):
        print("output_rows is empty")
    else:
        save_results(output_rows)

# %%
main_loop()
# Out:
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 404
# test method output:
# 	statistic: 5.512511590501951
# 	pvalue: 0.000999000999000999
# statisc method output: 20
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -0.038712824988120315
# 	pvalue: 0.6353646353646354
# statisc method output: 11
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: 0.03781113549437483
# 	pvalue: 0.6243756243756243
# statisc method output: 11
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: 0.5519409700063341
# 	pvalue: 0.3776223776223776
# statisc method output: 12
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# test method output:
# 	statistic: -2.5954870235704095
# 	pvalue: 1.0
# statisc method output: 11
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 404
# test method output:
# 	statistic: 0.532043205871812
# 	pvalue: 0.44155844155844154
# statisc method output: 12
# Running test with pair:
# 	- zeros({'shape': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -1.9461130618455926
# 	pvalue: 0.996003996003996
# statisc method output: 13
# Running test with pair:
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 402
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -0.0323341361642216
# 	pvalue: 0.6473526473526473
# statisc method output: 11
# Running test with pair:
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 402
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -0.003918663505955809
# 	pvalue: 0.6283716283716284
# statisc method output: 11
# Running test with pair:
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: 0.5024489765752287
# 	pvalue: 0.4155844155844156
# statisc method output: 12
# Running test with pair:
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# test method output:
# 	statistic: -2.4742836153448597
# 	pvalue: 1.0
# statisc method output: 11
# Running test with pair:
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 404
# test method output:
# 	statistic: 0.5811891380699621
# 	pvalue: 0.3866133866133866
# statisc method output: 12
# Running test with pair:
# 	- ones({'shape': (10, 2), 'dtype': <class 'numpy.int8'>}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -2.2338223222663345
# 	pvalue: 0.999000999000999
# statisc method output: 11
# Running self_compare test:
# Running test with pair:
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 404
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -0.9729082398944444
# 	pvalue: 0.8781218781218781
# statisc method output: 9
# Running test with pair:
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -3.974811965876232
# 	pvalue: 1.0
# statisc method output: 2
# Running test with pair:
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -3.3175533844307497
# 	pvalue: 1.0
# statisc method output: 4
# Running test with pair:
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# test method output:
# 	statistic: -2.969686101755734
# 	pvalue: 1.0
# statisc method output: 12
# Running test with pair:
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 404
# test method output:
# 	statistic: -4.241135809139925
# 	pvalue: 1.0
# statisc method output: 2
# Running test with pair:
# 	- uniform({'low': 0, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -6.963537862892309
# 	pvalue: 1.0
# statisc method output: 2
# Running self_compare test:
# Running test with pair:
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 404
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -0.9506869867975033
# 	pvalue: 0.8921078921078921
# statisc method output: 9
# Running test with pair:
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -4.269854986981626
# 	pvalue: 1.0
# statisc method output: 2
# Running test with pair:
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# test method output:
# 	statistic: -7.073367065729672
# 	pvalue: 1.0
# statisc method output: 2
# Running test with pair:
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 404
# test method output:
# 	statistic: -4.362782087669417
# 	pvalue: 1.0
# statisc method output: 2
# Running test with pair:
# 	- uniform({'low': 2000, 'high': 5000, 'size': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -6.867592319344356
# 	pvalue: 1.0
# statisc method output: 2
# Running self_compare test:
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 404
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 404
# test method output:
# 	statistic: -0.9359260287994329
# 	pvalue: 0.8791208791208791
# statisc method output: 9
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# test method output:
# 	statistic: -0.04385631399586513
# 	pvalue: 0.5804195804195804
# statisc method output: 19
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 404
# test method output:
# 	statistic: -3.8698648199789156
# 	pvalue: 1.0
# statisc method output: 3
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (10, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -6.706717254555125
# 	pvalue: 1.0
# statisc method output: 3
# Running self_compare test:
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 404
# test method output:
# 	statistic: 0.3017675170936684
# 	pvalue: 0.41058941058941056
# statisc method output: 103
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 404
# test method output:
# 	statistic: -6.451808576192103
# 	pvalue: 1.0
# statisc method output: 2
# Running test with pair:
# 	- uniform({'low': -1000, 'high': 1000, 'size': (100, 2)}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -14.090426646707284
# 	pvalue: 1.0
# statisc method output: 3
# Running test with pair:
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 10}), seed = 402
# 	- multivariate_normal({'mean': [0, 0], 'cov': [[1, 0], [0, 100]], 'size': 100}), seed = 404
# test method output:
# 	statistic: -0.5045547648036148
# 	pvalue: 0.7622377622377622
# statisc method output: 18
# Creating csv with field names:
# 	 dict_keys(['test_rslt_statistic', 'test_rslt_pvalue', 'statistic_rslt', 'independence_excepted', 'n', 'm', 'dataset_1_info', 'dataset_2_info'])

# %%
# Checking the data
import pandas as pd

df = pd.read_csv(_OUT_PATH)

# %%
# Were there any tests where statistic was greater than 'm+n'?
df[df['m']+df['n'] < df['statistic_rslt']]
# Out:
# Empty DataFrame
# Columns: [test_rslt_statistic, test_rslt_pvalue, statistic_rslt, independence_excepted, n, m, dataset_1_info, dataset_2_info]
# Index: []

# %%
# Were there any tests where statistic was less than 2?
df[2 > df['statistic_rslt']]
# Out:
# Empty DataFrame
# Columns: [test_rslt_statistic, test_rslt_pvalue, statistic_rslt, independence_excepted, n, m, dataset_1_info, dataset_2_info]
# Index: []

# %%
# Tests statistcs within expected range
df[2 <= df['statistic_rslt']][df['m']+df['n'] >= df['statistic_rslt']]
# Out:
#     test_rslt_statistic  test_rslt_pvalue  statistic_rslt  \
# 0              5.512512          0.000999              20
# 1             -0.038713          0.635365              11
# 2              0.037811          0.624376              11
# 3              0.551941          0.377622              12
# 4             -2.595487          1.000000              11
# 5              0.532043          0.441558              12
# 6             -1.946113          0.996004              13
# 7             -0.032334          0.647353              11
# 8             -0.003919          0.628372              11
# 9              0.502449          0.415584              12
# 10            -2.474284          1.000000              11
# 11             0.581189          0.386613              12
# 12            -2.233822          0.999001              11
# 13            -0.972908          0.878122               9
# 14            -3.974812          1.000000               2
# 15            -3.317553          1.000000               4
# 16            -2.969686          1.000000              12
# 17            -4.241136          1.000000               2
# 18            -6.963538          1.000000               2
# 19            -0.950687          0.892108               9
# 20            -4.269855          1.000000               2
# 21            -7.073367          1.000000               2
# 22            -4.362782          1.000000               2
# 23            -6.867592          1.000000               2
# 24            -0.935926          0.879121               9
# 25            -0.043856          0.580420              19
# 26            -3.869865          1.000000               3
# 27            -6.706717          1.000000               3
# 28             0.301768          0.410589             103
# 29            -6.451809          1.000000               2
# 30           -14.090427          1.000000               3
# 31            -0.504555          0.762238              18
#
#     independence_excepted    n    m  \
# 0                    True   10   10
# 1                    True   10   10
# 2                    True   10   10
# 3                    True   10   10
# 4                    True   10  100
# 5                    True   10   10
# 6                    True   10  100
# 7                    True   10   10
# 8                    True   10   10
# 9                    True   10   10
# 10                   True   10  100
# 11                   True   10   10
# 12                   True   10  100
# 13                  False   10   10
# 14                   True   10   10
# 15                   True   10   10
# 16                   True   10  100
# 17                   True   10   10
# 18                   True   10  100
# 19                  False   10   10
# 20                   True   10   10
# 21                   True   10  100
# 22                   True   10   10
# 23                   True   10  100
# 24                  False   10   10
# 25                   True   10  100
# 26                   True   10   10
# 27                   True   10  100
# 28                  False  100  100
# 29                   True  100   10
# 30                   True  100  100
# 31                   True   10  100
#
#                                        dataset_1_info  \
# 0   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 1   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 2   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 3   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 4   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 5   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 6   {'name': 'zeros', 'params': {'shape': (10, 2)}...
# 7   {'name': 'ones', 'params': {'shape': (10, 2), ...
# 8   {'name': 'ones', 'params': {'shape': (10, 2), ...
# 9   {'name': 'ones', 'params': {'shape': (10, 2), ...
# 10  {'name': 'ones', 'params': {'shape': (10, 2), ...
# 11  {'name': 'ones', 'params': {'shape': (10, 2), ...
# 12  {'name': 'ones', 'params': {'shape': (10, 2), ...
# 13  {'name': 'uniform', 'params': {'low': 0, 'high...
# 14  {'name': 'uniform', 'params': {'low': 0, 'high...
# 15  {'name': 'uniform', 'params': {'low': 0, 'high...
# 16  {'name': 'uniform', 'params': {'low': 0, 'high...
# 17  {'name': 'uniform', 'params': {'low': 0, 'high...
# 18  {'name': 'uniform', 'params': {'low': 0, 'high...
# 19  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 20  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 21  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 22  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 23  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 24  {'name': 'uniform', 'params': {'low': -1000, '...
# 25  {'name': 'uniform', 'params': {'low': -1000, '...
# 26  {'name': 'uniform', 'params': {'low': -1000, '...
# 27  {'name': 'uniform', 'params': {'low': -1000, '...
# 28  {'name': 'uniform', 'params': {'low': -1000, '...
# 29  {'name': 'uniform', 'params': {'low': -1000, '...
# 30  {'name': 'uniform', 'params': {'low': -1000, '...
# 31  {'name': 'multivariate_normal', 'params': {'me...
#
#                                        dataset_2_info
# 0   {'name': 'ones', 'params': {'shape': (10, 2), ...
# 1   {'name': 'uniform', 'params': {'low': 0, 'high...
# 2   {'name': 'uniform', 'params': {'low': 2000, 'h...
# 3   {'name': 'uniform', 'params': {'low': -1000, '...
# 4   {'name': 'uniform', 'params': {'low': -1000, '...
# 5   {'name': 'multivariate_normal', 'params': {'me...
# 6   {'name': 'multivariate_normal', 'params': {'me...
# 7   {'name': 'uniform', 'params': {'low': 0, 'high...
# 8   {'name': 'uniform', 'params': {'low': 2000, 'h...
# 9   {'name': 'uniform', 'params': {'low': -1000, '...
# 10  {'name': 'uniform', 'params': {'low': -1000, '...
# 11  {'name': 'multivariate_normal', 'params': {'me...
# 12  {'name': 'multivariate_normal', 'params': {'me...
# 13  {'name': 'uniform', 'params': {'low': 0, 'high...
# 14  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 15  {'name': 'uniform', 'params': {'low': -1000, '...
# 16  {'name': 'uniform', 'params': {'low': -1000, '...
# 17  {'name': 'multivariate_normal', 'params': {'me...
# 18  {'name': 'multivariate_normal', 'params': {'me...
# 19  {'name': 'uniform', 'params': {'low': 2000, 'h...
# 20  {'name': 'uniform', 'params': {'low': -1000, '...
# 21  {'name': 'uniform', 'params': {'low': -1000, '...
# 22  {'name': 'multivariate_normal', 'params': {'me...
# 23  {'name': 'multivariate_normal', 'params': {'me...
# 24  {'name': 'uniform', 'params': {'low': -1000, '...
# 25  {'name': 'uniform', 'params': {'low': -1000, '...
# 26  {'name': 'multivariate_normal', 'params': {'me...
# 27  {'name': 'multivariate_normal', 'params': {'me...
# 28  {'name': 'uniform', 'params': {'low': -1000, '...
# 29  {'name': 'multivariate_normal', 'params': {'me...
# 30  {'name': 'multivariate_normal', 'params': {'me...
# 31  {'name': 'multivariate_normal', 'params': {'me...
